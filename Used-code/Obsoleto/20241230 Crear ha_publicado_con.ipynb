# %%
dic = {
    'Andres Roger Arnau Notari': ['JM Calabuig', 'Y Wang', 'M Sanchis-Agudo', 'F Estelles', 'R Arnau', 'R Vinuesa', 'JM Pardo Gila', 'S Sanjuan', 'EAS Perez', 'C Catalan', 'N Jonard-Perez', 'E Erdogan', 'LM Garcia Raffi', 'DA Mendez', 'K Duraisamy', 'A Gonzalez', 'LM Garcia-Raffi', 'R Arnau', 'X Aguirre'],
    'Enrique A. Sanchez Perez' : ['F Torrens', 'A Alouani', 'J Rodriguez Ruiz', 'SO Crespo', 'J Rodriguez', 'D Valero', 'C Sanchez-Arnau', 'P Donat', 'LMG Raffi', 'A Fito-Bertran', 'R Sanchez-Perez', 'GR E CHECA F ROMAN', 'O Gok', 'MARIN', 'F Martmez-Gimenez', 'O Delgado Garrido', 'MDF Motilva', 'JoseM Sanchez-Cuadrado', 'P Tirado', 'J Sanchez Marin', 'WJ Ricker', 'G de Julian', 'E Sanchez Perez', 'C Sola', 'P Serra-Ano', 'R Aguilar', 'MFP Mancebo', 'A Manzano', 'F Sanchez-Martinez', 'A Fern', 'D Ginestar', 'OG Bravo', 'V Peset', 'A Anton', 'L Rivero', 'E Sanabria Codesal', 'FG Fontes', 'S Manzanares', 'JL de la Rosa', 'F de Campo', 'FXB Ferragud', 'W Ricker', 'A Vindel', 'S Oltra', 'P Tradacete Perez', 'R del Campo', 'I Steinwart', 'OV Sierra', 'X Garcia Masso', 'JM Sanchez Cuadrado', 'MJ Felipe', 'R Yahi', 'D Werner' 'E Fuster', 'P Tradacete', 'EM Navarrete', 'JM Ruiz', 'F Mayoral Masa', 'A Ferrer Sapena', 'F Mayoral', 'E Checa Martinez', 'E Dahia', 'S Lajara', 'A Defant', 'B Murillo Lopez', 'A Sarrion', 'A Fuster', 'A Manetti', 'JS Marin', 'C Vidal', 'E Jimenez-Fernandez', 'C Perez-Belles', 'P Rueda', 'MS Novales', 'E Pieroni', 'MA Juan', 'F Martinez-Gimenez', 'EA Martinez', 'EJ Fernandez', 'MF Unzueta', 'MJ Perez', 'MA Juan Blanco', 'S Oltra', 'F Galaz-Fontes', 'IS del Toro', 'C Alegre', 'JV Salcedo', 'E Fuster-Garcia', 'SPEA Falciani H.', 'R Samino', 'A Delicado', 'J Marin', 'E Sanchez-Arnau', 'E Jimenez Fernandez', 'V Vallejo', 'IF Palomares', 'F Peset', 'OGBG Bravo', 'S Del Campo Canizares', 'JM Chica Olmo', 'MA Sanchez Dominguez', 'X Blasco', 'H FALCIANI', 'P Gregori', 'L Agud', 'ED Candel', 'A Vidal-Infer', 'C Ariza', 'JA Lopez Molina', 'LM Gonzalez', 'I Ferrando',
Juan Blanco', 'F Galaz-Fontes', 'E Raso', 'M Fernandez Unzueta', 'IS del Toro', 'CV Cabo', 'DA Mendez', 'A Garcia-Valiente', 'S Manzanares', 'RA Kycia', 'JL de la Rosa', 'A Gonzalez', 'SD Toro', 'E Jimenez Fernandez', 'L Cotino Hueso', 'O Delgado', 'I Ferrando Palomares', 'F Peset', 'R Arnau', 'C Gallart-Palau', 'O Blasco'] 
}

# %%
import pandas as pd

# Read the entire CSV as a text file and extract unique names
with open('ha_publicado_con_JMCalabuig.csv', 'r') as file:
    content = file.read()

# Split the content by semicolons, flatten, and clean
all_names = set([name.strip() for name in content.split(';') if name.strip()])

# Display the unique names
print(all_names)
# Out:
# {'JM Calabuig', 'J Rodriguez Ruiz', 'J Rodriguez', 'AF Sapena', 'A Niemczynowicz', 'P Gregori', 'L Agud', 'AR Arnau-Notari', 'LMG Raffi', 'EM Navarrete', 'E Fuster', 'C Vidal Cabo', 'F Estelles\nJM Calabuig', 'X Aguirre', 'AR Arnau Notari', 'M Isabel', 'Pea Sanchez', 'I Ferrando', 'A Ferrer Sapena', 'JM Pardo Gila', 'S Sanjuan', 'S Lajara', 'EAS Perez', 'T Signes', 'EA Sanchez Perez', 'M Fernandez-Unzueta', 'C Catalan', 'A Siemaszko', 'MF Peset Mancebo', 'M Jaworski', 'JS Bejarano-Ballen', 'E Jimenez-Fernandez', 'P Rueda', 'MFP Mancebo', 'E Erdogan', 'MA Juan', 'OG Bravo', 'LM Garcia Raffi', 'EJ Fernandez', 'MF Unzueta', 'H Falciani', 'MA Juan Blanco', 'F Galaz-Fontes', 'E Raso', 'M Fernandez Unzueta', 'IS del Toro', 'CV Cabo', 'DA Mendez', 'A Garcia-Valiente', 'S Manzanares', 'RA Kycia', 'JL de la Rosa', 'A Gonzalez', 'SD Toro', 'E Jimenez Fernandez', 'L Cotino Hueso', 'O Delgado', 'I Ferrando Palomares', 'JMC Rodriguez', 'F Peset', 'R Arnau', 'C Gallart-Palau', 'O Blasco'}

# %%
# Transform the dictionary into a DataFrame
df = pd.DataFrame({'nombre': dic.keys(), 'otros_inv': [', '.join(values) for values in dic.values()]})

# Save to CSV
output_path = 'ha_publicado_con.csv'
df.to_csv(output_path, index=False)

# Display the DataFrame
print(df)
# Out:
#                            nombre  \
# 0       Andres Roger Arnau Notari
# 1        Enrique A. Sanchez Perez
# 2  Jose Manuel Calabuig Rodriguez
#
#                                            otros_inv
# 0  JM Calabuig, Y Wang, M Sanchis-Agudo, F Estell...
# 1  F Torrens, A Alouani, J Rodriguez Ruiz, SO Cre...
# 2  JM Calabuig, J Rodriguez Ruiz, J Rodriguez, AF...
